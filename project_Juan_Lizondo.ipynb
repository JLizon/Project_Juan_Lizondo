# %% [markdown]
# ## The dataset
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real homes published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive home in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd
# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### What is the most expensive home in the dataset? (★☆☆)

# %%
max_price_index = ds['price'].idxmax()
print(ds.loc[max_price_index])
# Out:
# Unnamed: 0                                                      13111
# id_realEstates                                              132042636
# isNew                                                           False
# realEstate_name                            engel volkers torrelodones
# phone_realEstate                                          911798512.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/vi...
# rooms                                                            19.0
# bathrooms                                                         NaN
# surface                                                           NaN
# price                                                         8500000
# date                                             2019-12-19T12:29:00Z
# description         El Palacio de El Enebral, la finca fue propied...
# address                                                   El Escorial
# ...

# %% [markdown]
# #### What is cheapest home in the dataset? (★☆☆)

# %%
min_price_index = ds['price'].idxmin()
print(ds.loc[min_price_index])
# Out:
# Unnamed: 0                                                        367
# id_realEstates                                              153637952
# isNew                                                           False
# realEstate_name                                                esalje
# phone_realEstate                                          912786497.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             4.0
# bathrooms                                                         4.0
# surface                                                         262.0
# price                                                               0
# date                                      2019-12-28T18:52:25.965658Z
# description         ESALJE vende amplio pareado de 268 m2. distrib...
# address                                                         Parla
# ...

# %% [markdown]
# #### What is the biggest and the smallest home in the dataset? (★☆☆)

# %%
ds = pd.read_csv('assets/real_estate.csv', sep=';')
max_surface_index = ds['surface'].idxmax()
print(ds.loc[max_surface_index])
# Out:
# Unnamed: 0                                                       6795
# id_realEstates                                              153936192
# isNew                                                           False
# realEstate_name                               habitarium inmobiliaria
# phone_realEstate                                          916357732.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             3.0
# bathrooms                                                         2.0
# surface                                                      249000.0
# price                                                          289000
# date                                             2019-12-25T18:30:00Z
# description         Zona Centro. Chalet pareado de esquina de 249m...
# address                                              Sevilla la Nueva
# ...

# %%
min_surface_index = ds['surface'].idxmin()
print(ds.loc[min_surface_index])
# Out:
# Unnamed: 0                                                        499
# id_realEstates                                              152817874
# isNew                                                           False
# realEstate_name                                              toledo21
# phone_realEstate                                          910757382.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             1.0
# bathrooms                                                         1.0
# surface                                                          15.0
# price                                                           85000
# date                                     2019-12-28T19:04:44.6433814Z
# description         ¡NO BUSQUES MÁS, YA LA HAS ENCONTRADO! . \n \n...
# address                                 Calle Amparo,  Madrid Capital
# ...

# %% [markdown]
# How many populations (level5) the dataset contains?####  (★☆☆)

# %%
level_5 = len((ds['level5'].value_counts()))
print(level_5)
number_level_5 = (ds['level5'].value_counts())
print(number_level_5)
# Out:
# 168
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Brea de Tajo               1
# El Atazar                  1
# Piñuécar-gandullas         1
# Braojos                    1
# Montejo de la Sierra       1
# Name: count, Length: 168, dtype: int64

# %% [markdown]
# #### Does the dataset contain NAs? (★☆☆)

# %%
ds.isnull().values.any()
# Out:
# True

# %% [markdown]
# #### Delete the NAs of the dataset, if applicable (★★☆)

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# ...

# %% [markdown]
# #### What is the mean of prices in the population (level5) of "Arroyomolinos (Madrid)"? (★★☆)

# %%
arroyomolinos = ds.loc[ds['level5']=="Arroyomolinos (Madrid)"]
median_price = arroyomolinos['price'].median()
print(median_price)
# Out:
# 289000.0

# %% [markdown]
# #### Plot the histogram of prices for the population (level5) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 5))

plt.hist(arroyomolinos['price'], bins = 30, alpha = 0.7)

plt.title("Histogram")
plt.show()

# %% [markdown]
# #### Now let's work with the "south belt" of madrid. Make a subsetting that contains the following populations (level5): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)

# %%
Fuenlabrada_south = ds.loc[ds['level5']=="Fuenlabrada"]
Leganes_south = ds.loc[ds['level5']=="Leganés"]
Getafe_south = ds.loc[ds['level5']=="Getafe"]
Alcorcon_south = ds.loc[ds['level5']=="Alcorcón"]
south_belt_all = Fuenlabrada_south + Leganes_south + Getafe_south + Alcorcon_south
print(south_belt_all)

south_belt = ds.loc[ds['level5']=="Fuenlabrada"]+ds.loc[ds['level5']=="Leganés"]+ds.loc[ds['level5']=="Getafe"]+ds.loc[ds['level5']=="Alcorcón"]
print(len(south_belt))
# Out:
#        Unnamed: 0  id_realEstates isNew realEstate_name  phone_realEstate  \
# 1             NaN             NaN   NaN             NaN               NaN
# 3             NaN             NaN   NaN             NaN               NaN
# 85            NaN             NaN   NaN             NaN               NaN
# 94            NaN             NaN   NaN             NaN               NaN
# 109           NaN             NaN   NaN             NaN               NaN
# ...           ...             ...   ...             ...               ...
# 15275         NaN             NaN   NaN             NaN               NaN
# 15291         NaN             NaN   NaN             NaN               NaN
# 15305         NaN             NaN   NaN             NaN               NaN
# 15322         NaN             NaN   NaN             NaN               NaN
# 15325         NaN             NaN   NaN             NaN               NaN
#
#       url_inmueble  rooms  bathrooms  surface  price  ... level4Id level5Id  \
# ...

# %% [markdown]
# #### Make a bar plot of the median of prices (★★★)

# %%
Fuenlabrada_price = ds.loc[ds['level5']=="Fuenlabrada"]
precio_FUE = (Fuenlabrada_price['price']).mean()
Leganes_price= ds.loc[ds['level5']=="Leganés"]
precio_LEG = (Leganes_price['price']).mean()
Getafe_price= ds.loc[ds['level5']=="Getafe"]
precio_GTF = (Getafe_price['price']).mean()
Alcorcon_price= ds.loc[ds['level5']=="Alcorcón"]
precio_ALC = (Alcorcon_price['price']).mean()

labels = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
values = [precio_FUE, precio_LEG, precio_GTF, precio_ALC]

plt.figure(figsize=(10, 5))
plt.bar(labels, values)
plt.title("Bar Plot of Median Prices")
plt.show()

# %% [markdown]
# #### Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (★★★)

# %%
median_prices = ds['price'].mean()
print("Median prices:", median_prices)
variance_prices = ds['price'].var()
print("Variance prices:", variance_prices)
median_rooms = ds['rooms'].mean()
print("Variance rooms:",median_rooms)
variance_rooms = ds['rooms'].var()
print("Variance rooms:",variance_rooms)
median_surface = ds['surface'].mean()
print("Variance surface:",median_surface)
variance_surface = ds['surface'].var()
print("Variance surface:",variance_surface)
median_bathrooms = ds['bathrooms'].mean()
print("Variance bathrooms:",median_bathrooms)
variance_bathrooms = ds['bathrooms'].var()
print("Variance bathrooms:",variance_bathrooms)
# Out:
# Median prices: 477303.56641669385
# Variance prices: 349628868677.4539
# Variance rooms: 3.2316112668535575
# Variance rooms: 1.9407455379492797
# Variance surface: 196.91643592474264
# Variance surface: 4764433.8520764755
# Variance bathrooms: 2.150233488992662
# Variance bathrooms: 1.669469222949398

# %% [markdown]
# #### What is the most expensive home of each population? (★★☆)

# %%
precio_FUE_max = (Fuenlabrada_price['price']).max()
print("Fuenlabrada=", precio_FUE_max)
precio_LEG_max = (Leganes_price['price']).max()
print("Leganés=",precio_LEG_max)
precio_GTF_max = (Getafe_price['price']).max()
print("Getafe=",precio_GTF_max)
precio_ALC_max = (Alcorcon_price['price']).max()
print("Alcorcón=",precio_ALC_max)
# Out:
# Fuenlabrada= 490000
# Leganés= 650000
# Getafe= 1050000
# Alcorcón= 950000

# %% [markdown]
# #### Normalize the variable of prices for each population and plot the 4 histograms in the same plot (★★★)

# %%
plt.figure(figsize = (10, 5))

plt.hist(precio_FUE_all, bins = 30, alpha = 0.7, label = "Fuenlabrada")
plt.hist(precio_LEG_all, bins = 30, alpha = 0.7, label = "Leganés")
plt.hist(precio_GTF_all, bins = 30, alpha = 0.7, label = "Getafe")
plt.hist(precio_ALC_all, bins = 30, alpha = 0.7, label = "Alcorcón")

plt.title("Histograma")
plt.show()

# %% [markdown]
# #### Make a plot of the coordinates (lat and long) of the south belt of Madrid by color of each population (★★★★)
# This is a extremely hard exercise and we highly recommend to do it at the end of everything

# %%
# Run in console the following command before run the rest of code:
# jupyter nbextension enable --py --sys-prefix ipyleaflet

from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## HERE: plot the coordinates of the estates
latitud_FUE = 40.28419
longitud_FUE = -3.7941
latitud_LEG = 40.32718
longitud_LEG = -3.7635
latitud_GTF = 40.30571
longitud_GTF = -3.7329
latitud_ALC = 40.34582
longitud_ALC = -3.8248

## PUT HERE YOUR CODE:
plt.figure(figsize = (10, 5))

plt.scatter(latitud_FUE, longitud_FUE, label = "Fuenlabrada")
plt.scatter(latitud_LEG, longitud_LEG, label = "Leganés")
plt.scatter(latitud_GTF, longitud_GTF, label = "Getafe")
plt.scatter(latitud_ALC, longitud_ALC, label = "Alcorcón")

plt.title("Gráfico de dispersión")
plt.legend()
plt.show()

# %% [markdown]
# #### What can you say about the price per square meter between the towns of Getafe and Alcorcón?

# %%
Getafe_price = ds.loc[ds['level5']=="Getafe"]
Alcorcon_price = ds.loc[ds['level5']=="Alcorcón"]
precio_per_square_ALC = (Alcorcon_price['price']/Alcorcon_price['surface']).median()
precio_per_square_GTF = (Getafe_price['price']/Getafe_price['surface']).median()
print("Getafe", precio_per_square_GTF)
print("Alcorcón", precio_per_square_ALC)
print("El metro cuadrado en Alcorcón es ligeramente más caro")
# Out:
# Getafe 1973.3333333333333
# Alcorcón 2207.7922077922076
# El metro cuadrado en Alcorcón es ligeramente más caro

# %% [markdown]
# #### Reload the data, is the average of "Valdemorillo" and "Galapagar" prices the same?

# %%
Valdemorillo_price = ds.loc[ds['level5']=="Valdemorillo"]
precio_VAL = (Valdemorillo_price['price']).mean()
Galapagar_price = ds.loc[ds['level5']=="Galapagar"]
precio_GAL = (Galapagar_price['price']).mean()
print(precio_VAL)
print(precio_GAL)
print("El precio medio de las dos localidades es muy parecido")
# Out:
# 363860.2931034483
# 360063.20238095237
# El precio medio de las dos localidades es muy parecido

# %% [markdown]
# #### What happens if we do the same analysis for price/m2 (★★☆)

# %%
Valdemorillo_price = ds.loc[ds['level5']=="Valdemorillo"]
precio_per_square_VAL = (Valdemorillo_price['price']/Valdemorillo_price['surface']).mean()
Galapagar_price = ds.loc[ds['level5']=="Galapagar"]
precio_per_square_GAL = (Galapagar_price['price']/Galapagar_price['surface']).mean()
print(precio_per_square_VAL)
print(precio_per_square_GAL)
print("La pequeña oscilación en positivo que tenía valdemorillo en el precio medio, varía significativamente en el precio por metro cuadrado en favor de Galapagar")
# Out:
# 1317.9502109024986
# 1606.3240303094024
# La pequeña oscilación en positivo que tenía valdemorillo en el precio medio, varía significativamente en el precio por metro cuadrado en favor de Galapagar

# %% [markdown]
# #### Could you say there is a relation between surface and price? (★★☆)
# Hint: make a scatter plot.

# %%
precio_per_square_VAL_all = (Valdemorillo_price['price']/Valdemorillo_price['surface'])
precio_per_square_GAL_all = (Galapagar_price['price']/Galapagar_price['surface'])
precio_VAL_all = (Valdemorillo_price['price'])
precio_GAL_all = (Galapagar_price['price'])

plt.figure(figsize = (10, 5))

plt.scatter(precio_per_square_VAL_all, precio_VAL_all, label = "Valdemorillo")
plt.scatter(precio_per_square_GAL_all, precio_GAL_all, label = "Galapagar")

plt.title("Gráfico de dispersión")
plt.legend()
plt.show()

# %% [markdown]
# #### Make the same plot for 4 different populations (level5) and rearrange them on the same graph? (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
Alcobendas_price = ds.loc[ds['level5']=="Alcobendas"]
Alcala_de_Henares_price = ds.loc[ds['level5']=="Alcalá de Henares"]
Las_Rozas_price = ds.loc[ds['level5']=="Las Rozas"]
Fuenlabrada_price = ds.loc[ds['level5']=="Fuenlabrada"]
Leganes_price = ds.loc[ds['level5']=="Leganés"]
precio_ALC_all = (Alcobendas_price['price'])
precio_ALH_all = (Alcala_de_Henares_price['price'])
precio_LRZ_all = (Las_Rozas_price['price'])
precio_FUE_all = (Fuenlabrada_price['price'])
precio_LEG_all = (Leganes_price['price'])
precio_GTF_all = (Getafe_price['price'])
precio_per_square_ALC_all = (Alcobendas_price['price']/Alcobendas_price['surface'])
precio_per_square_ALH_all = (Alcala_de_Henares_price['price']/Alcala_de_Henares_price['surface'])
precio_per_square_LRZ_all = (Las_Rozas_price['price']/Las_Rozas_price['surface'])
precio_per_square_FUE_all = (Fuenlabrada_price['price']/Fuenlabrada_price['surface'])
precio_per_square_LEG_all = (Leganes_price['price']/Leganes_price['surface'])


plt.figure(figsize = (20, 10))

plt.scatter(precio_per_square_ALH_all, precio_ALH_all, label = "Alcalá de Henares")
plt.scatter(precio_per_square_LRZ_all, precio_LRZ_all, label = "Las Rozas")
plt.scatter(precio_per_square_FUE_all, precio_FUE_all, label = "Fuenlabrada")
plt.scatter(precio_per_square_LEG_all, precio_LEG_all, label = "Leganés")

plt.title("Gráfico de dispersión")
plt.legend()
plt.show()

# %% [markdown]
# #### How many  real estate agencies the dataset contains? (★★☆)

# %%
realstate_agency_len = len(ds['realEstate_name'].value_counts())
print(realstate_agency_len)
realstate_agency = (ds['realEstate_name'].value_counts())
print(realstate_agency)
# Out:
# 1821
# realEstate_name
# engel volkers madrid    470
# infocasa consulting     300
# outletdeviviendas       260
# housell                 250
# solvia inmobiliaria     207
#                        ...
# javier garcia             1
# ir inmobiliaria           1
# jesus                     1
# julio                     1
# nieves                    1
# Name: count, Length: 1821, dtype: int64

# %% [markdown]
# #### What is the population (level 5) that contains the most houses? (★★☆)

# %%
number_level_5 = (ds['level5'].value_counts().idxmax())
print(number_level_5)
# Out:
#  Madrid Capital
